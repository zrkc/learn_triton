# %%
# !nvidia-smi
# Out:
# Wed Mar  4 14:00:03 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !sudo apt update
# !sudo apt install build-essential
# !pip install numpy matplotlib pandas torch triton pytest
# !pip install --upgrade torch
# !pip install --upgrade triton

# %%
# !git clone https://github.com/zrkc/learn_triton.git
# %cd learn_triton/

# %%
# !git pull

# %%
# !python tutorials/vector_addition.py
# Out:
# tensor([1.3713, 1.3076, 0.4940,  ..., 0.4024, 1.7918, 1.0686], device='cuda:0')
# tensor([1.3713, 1.3076, 0.4940,  ..., 0.4024, 1.7918, 1.0686], device='cuda:0')
# The maximum difference between torch and triton is 0.0
